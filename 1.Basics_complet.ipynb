# %%
df1 = spark.read.format("json").load("dbfs:/FileStore/shared_uploads/filetechn@gmail.com/people-1.json")

# %%
df1.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|    Fer|
# |  20|Michael|
# |  15|    Ana|
# +----+-------+

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>name</th></tr></thead><tbody><tr><td>null</td><td>Fer</td></tr><tr><td>20</td><td>Michael</td></tr><tr><td>15</td><td>Ana</td></tr></tbody></table></div>

# %%
df1.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df1.columns
# Out:
# Out[5]: ['age', 'name']

# %%
df1.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              17.5|   null|
# | stddev|3.5355339059327378|   null|
# |    min|                15|    Ana|
# |    max|                20|Michael|
# +-------+------------------+-------+

# %% [markdown]
# ## CREATE COLUMN

# %%
df1.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|    Fer|
# |  20|Michael|
# |  15|    Ana|
# +----+-------+

# %%
df2 = df1.withColumn('newname',df1['name'])

# %%
df2.show()
# Out:
# +----+-------+-------+
# | age|   name|newname|
# +----+-------+-------+
# |null|    Fer|    Fer|
# |  20|Michael|Michael|
# |  15|    Ana|    Ana|
# +----+-------+-------+

# %% [markdown]
# ## CREATE COLUMNS WITH OPERATION

# %%
df2.show()
# Out:
# +----+-------+-------+
# | age|   name|newname|
# +----+-------+-------+
# |null|    Fer|    Fer|
# |  20|Michael|Michael|
# |  15|    Ana|    Ana|
# +----+-------+-------+

# %%
df_x = df2.withColumn('age_new',df2['age']*2)

# %%
df_x.show()
# Out:
# +----+-------+-------+-------+
# | age|   name|newname|age_new|
# +----+-------+-------+-------+
# |null|    Fer|    Fer|   null|
# |  20|Michael|Michael|     40|
# |  15|    Ana|    Ana|     30|
# +----+-------+-------+-------+

# %% [markdown]
# # RENAMED COLUMN

# %%
df_x.show()
# Out:
# +----+-------+-------+-------+
# | age|   name|newname|age_new|
# +----+-------+-------+-------+
# |null|    Fer|    Fer|   null|
# |  20|Michael|Michael|     40|
# |  15|    Ana|    Ana|     30|
# +----+-------+-------+-------+

# %%
df = df_x

# %%
df2 = df.withColumnRenamed('age_new','renamed_age')

# %%
df2.show()
# Out:
# +----+-------+-------+-----------+
# | age|   name|newname|renamed_age|
# +----+-------+-------+-----------+
# |null|    Fer|    Fer|       null|
# |  20|Michael|Michael|         40|
# |  15|    Ana|    Ana|         30|
# +----+-------+-------+-----------+

# %% [markdown]
# ## QUERY IN SPARK SQL

# %%
df2.show()
# Out:
# +----+-------+-------+-----------+
# | age|   name|newname|renamed_age|
# +----+-------+-------+-----------+
# |null|    Fer|    Fer|       null|
# |  20|Michael|Michael|         40|
# |  15|    Ana|    Ana|         30|
# +----+-------+-------+-----------+

# %%
df2.createOrReplaceTempView('data')

# %%
query = spark.sql("SELECT * FROM data")

# %%
query.show()
# Out:
# +----+-------+-------+-----------+
# | age|   name|newname|renamed_age|
# +----+-------+-------+-----------+
# |null|    Fer|    Fer|       null|
# |  20|Michael|Michael|         40|
# |  15|    Ana|    Ana|         30|
# +----+-------+-------+-----------+

# %%
## Query  """"""

# %%
query2 = spark.sql("""
SELECT 
* 
FROM
data""")

# %%
display(query2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>name</th><th>newname</th><th>renamed_age</th></tr></thead><tbody><tr><td>null</td><td>Fer</td><td>Fer</td><td>null</td></tr><tr><td>20</td><td>Michael</td><td>Michael</td><td>40</td></tr><tr><td>15</td><td>Ana</td><td>Ana</td><td>30</td></tr></tbody></table></div>
