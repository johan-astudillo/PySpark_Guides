# %% [markdown]
# ## For www.filetechn.com

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import pyspark.pandas as ps


filename = "data_excel.xlsx"
folder = 'dbfs:/FileStore/shared_uploads/filetechn@gmail.com/'
url = folder + filename

read = ps.read_excel(url, sheet_name="data")

df = read.to_spark()

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>1</td><td>Juan</td><td>20</td></tr><tr><td>2</td><td>Michael</td><td>30</td></tr><tr><td>3</td><td>Pedro</td><td>60</td></tr><tr><td>4</td><td>Jefferson</td><td>70</td></tr><tr><td>5</td><td>Jey</td><td>80</td></tr><tr><td>6</td><td>Juan</td><td>90</td></tr><tr><td>7</td><td>Diego</td><td>90</td></tr></tbody></table></div>

# %%
#NOTEBOOK IN DESCRIPTION
