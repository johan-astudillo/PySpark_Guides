# %%
df1 = spark.read.format("json").load("dbfs:/FileStore/shared_uploads/filetechn@gmail.com/people-1.json")

# %%
df1.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|    Fer|
# |  20|Michael|
# |  15|    Ana|
# +----+-------+

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>name</th></tr></thead><tbody><tr><td>null</td><td>Fer</td></tr><tr><td>20</td><td>Michael</td></tr><tr><td>15</td><td>Ana</td></tr></tbody></table></div>

# %%
df1.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df1.columns
# Out:
# Out[5]: ['age', 'name']

# %%
df1.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              17.5|   null|
# | stddev|3.5355339059327378|   null|
# |    min|                15|    Ana|
# |    max|                20|Michael|
# +-------+------------------+-------+
