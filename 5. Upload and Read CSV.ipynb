# %% [markdown]
# ## For www.filetechn.com

# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/filetechn@gmail.com/data-2.csv")

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>1</td><td>Juan</td><td>20</td></tr><tr><td>2</td><td>Michael</td><td>30</td></tr><tr><td>3</td><td>Pedro</td><td>60</td></tr><tr><td>4</td><td>Jefferson</td><td>70</td></tr><tr><td>5</td><td>Jey</td><td>80</td></tr><tr><td>6</td><td>Juan</td><td>90</td></tr><tr><td>7</td><td>Diego</td><td>90</td></tr></tbody></table></div>

# %%
df1.show()
# Out:
# +---+---------+---+
# | ID|     Name|Age|
# +---+---------+---+
# |  1|     Juan| 20|
# |  2|  Michael| 30|
# |  3|    Pedro| 60|
# |  4|Jefferson| 70|
# |  5|      Jey| 80|
# |  6|     Juan| 90|
# |  7|    Diego| 90|
# +---+---------+---+

# %% [markdown]
# # ALSO

# %%
df = (spark.read
              .option("sep", ",")
              .option("header", "true")
              .option("encoding", "ISO-8859-1")
              .csv("dbfs:/FileStore/shared_uploads/filetechn@gmail.com/data-2.csv")
              )

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>1</td><td>Juan</td><td>20</td></tr><tr><td>2</td><td>Michael</td><td>30</td></tr><tr><td>3</td><td>Pedro</td><td>60</td></tr><tr><td>4</td><td>Jefferson</td><td>70</td></tr><tr><td>5</td><td>Jey</td><td>80</td></tr><tr><td>6</td><td>Juan</td><td>90</td></tr><tr><td>7</td><td>Diego</td><td>90</td></tr></tbody></table></div>
