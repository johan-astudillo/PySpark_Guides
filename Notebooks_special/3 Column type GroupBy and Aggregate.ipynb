# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/filetechn@gmail.com/sales_info.csv")

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>Person</th><th>Sales</th></tr></thead><tbody><tr><td>GOOG</td><td>Sam</td><td>200</td></tr><tr><td>GOOG</td><td>Charlie</td><td>120</td></tr><tr><td>GOOG</td><td>Frank</td><td>340</td></tr><tr><td>MSFT</td><td>Tina</td><td>600</td></tr><tr><td>MSFT</td><td>Amy</td><td>124</td></tr><tr><td>MSFT</td><td>Vanessa</td><td>243</td></tr><tr><td>FB</td><td>Carl</td><td>870</td></tr><tr><td>FB</td><td>Sarah</td><td>350</td></tr><tr><td>APPL</td><td>John</td><td>250</td></tr><tr><td>APPL</td><td>Linda</td><td> 130</td></tr><tr><td>APPL</td><td>Mike</td><td> 750</td></tr><tr><td>APPL</td><td> Chris</td><td> 350</td></tr></tbody></table></div>

# %% [markdown]
# # Change column type

# %%
# is a integer, but show in String
df1.printSchema()
# Out:
# root
#  |-- Company: string (nullable = true)
#  |-- Person: string (nullable = true)
#  |-- Sales: string (nullable = true)

# %%
# then 1 Import Library...
from pyspark.sql.types import IntegerType

df1 = df1.withColumn('Sales', df1['Sales'].cast(IntegerType()))

# %%
df1.printSchema()
# Out:
# root
#  |-- Company: string (nullable = true)
#  |-- Person: string (nullable = true)
#  |-- Sales: integer (nullable = true)

# %% [markdown]
# # GROUP BY

# %%
display(df1.groupBy('Company').count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>count</th></tr></thead><tbody><tr><td>APPL</td><td>4</td></tr><tr><td>GOOG</td><td>3</td></tr><tr><td>FB</td><td>2</td></tr><tr><td>MSFT</td><td>3</td></tr></tbody></table></div>

# %%
display(df1.groupBy('Company').max('Sales'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>max(Sales)</th></tr></thead><tbody><tr><td>APPL</td><td>750</td></tr><tr><td>GOOG</td><td>340</td></tr><tr><td>FB</td><td>870</td></tr><tr><td>MSFT</td><td>600</td></tr></tbody></table></div>

# %%
# with columns
df1.agg({'Sales':'Sum'}).show()
# Out:
# +----------+
# |sum(Sales)|
# +----------+
# |      4327|
# +----------+

# %%
group_data = df1.groupBy('Company')

# %%
group_data.agg({'Sales':'max'}).show()
# Out:
# +-------+----------+
# |Company|max(Sales)|
# +-------+----------+
# |   APPL|       750|
# |   GOOG|       340|
# |     FB|       870|
# |   MSFT|       600|
# +-------+----------+

# %% [markdown]
# # avg, stddev, countdistinct

# %%
from pyspark.sql.functions import countDistinct,avg,stddev

# %%
# avg
df1.select(avg('Sales').alias('Avarage Sales')).show()
# Out:
# +-----------------+
# |    Avarage Sales|
# +-----------------+
# |360.5833333333333|
# +-----------------+

# %%
df1.select(stddev('Sales')).show()
# Out:
# +------------------+
# |stddev_samp(Sales)|
# +------------------+
# |250.08742410799007|
# +------------------+

# %% [markdown]
# ## FORMAT TO VALUES NUMERICS

# %%
sales_std = df1.select(stddev("Sales").alias('std'))

# %%
display(sales_std)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>std</th></tr></thead><tbody><tr><td>250.08742410799007</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import format_number

# %%
# 2 decimals
display(sales_std.select(format_number('std', 2)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format_number(std, 2)</th></tr></thead><tbody><tr><td>250.09</td></tr></tbody></table></div>

# %% [markdown]
# # ORDER BY

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>Person</th><th>Sales</th></tr></thead><tbody><tr><td>GOOG</td><td>Sam</td><td>200</td></tr><tr><td>GOOG</td><td>Charlie</td><td>120</td></tr><tr><td>GOOG</td><td>Frank</td><td>340</td></tr><tr><td>MSFT</td><td>Tina</td><td>600</td></tr><tr><td>MSFT</td><td>Amy</td><td>124</td></tr><tr><td>MSFT</td><td>Vanessa</td><td>243</td></tr><tr><td>FB</td><td>Carl</td><td>870</td></tr><tr><td>FB</td><td>Sarah</td><td>350</td></tr><tr><td>APPL</td><td>John</td><td>250</td></tr><tr><td>APPL</td><td>Linda</td><td>130</td></tr><tr><td>APPL</td><td>Mike</td><td>750</td></tr><tr><td>APPL</td><td> Chris</td><td>350</td></tr></tbody></table></div>

# %%
display( df1.orderBy(df1['Sales'].desc())  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>Person</th><th>Sales</th></tr></thead><tbody><tr><td>FB</td><td>Carl</td><td>870</td></tr><tr><td>APPL</td><td>Mike</td><td>750</td></tr><tr><td>MSFT</td><td>Tina</td><td>600</td></tr><tr><td>FB</td><td>Sarah</td><td>350</td></tr><tr><td>APPL</td><td> Chris</td><td>350</td></tr><tr><td>GOOG</td><td>Frank</td><td>340</td></tr><tr><td>APPL</td><td>John</td><td>250</td></tr><tr><td>MSFT</td><td>Vanessa</td><td>243</td></tr><tr><td>GOOG</td><td>Sam</td><td>200</td></tr><tr><td>APPL</td><td>Linda</td><td>130</td></tr><tr><td>MSFT</td><td>Amy</td><td>124</td></tr><tr><td>GOOG</td><td>Charlie</td><td>120</td></tr></tbody></table></div>

# %%
 # OR ASC FOR DEFAULT
display( df1.orderBy(df1['Sales'])  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>Person</th><th>Sales</th></tr></thead><tbody><tr><td>GOOG</td><td>Charlie</td><td>120</td></tr><tr><td>MSFT</td><td>Amy</td><td>124</td></tr><tr><td>APPL</td><td>Linda</td><td>130</td></tr><tr><td>GOOG</td><td>Sam</td><td>200</td></tr><tr><td>MSFT</td><td>Vanessa</td><td>243</td></tr><tr><td>APPL</td><td>John</td><td>250</td></tr><tr><td>GOOG</td><td>Frank</td><td>340</td></tr><tr><td>FB</td><td>Sarah</td><td>350</td></tr><tr><td>APPL</td><td> Chris</td><td>350</td></tr><tr><td>MSFT</td><td>Tina</td><td>600</td></tr><tr><td>APPL</td><td>Mike</td><td>750</td></tr><tr><td>FB</td><td>Carl</td><td>870</td></tr></tbody></table></div>

# %%
 # IS NOT NECESSARY ASC
display( df1.orderBy(df1['Sales'].asc())  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Company</th><th>Person</th><th>Sales</th></tr></thead><tbody><tr><td>GOOG</td><td>Charlie</td><td>120</td></tr><tr><td>MSFT</td><td>Amy</td><td>124</td></tr><tr><td>APPL</td><td>Linda</td><td>130</td></tr><tr><td>GOOG</td><td>Sam</td><td>200</td></tr><tr><td>MSFT</td><td>Vanessa</td><td>243</td></tr><tr><td>APPL</td><td>John</td><td>250</td></tr><tr><td>GOOG</td><td>Frank</td><td>340</td></tr><tr><td>FB</td><td>Sarah</td><td>350</td></tr><tr><td>APPL</td><td> Chris</td><td>350</td></tr><tr><td>MSFT</td><td>Tina</td><td>600</td></tr><tr><td>APPL</td><td>Mike</td><td>750</td></tr><tr><td>FB</td><td>Carl</td><td>870</td></tr></tbody></table></div>
